# %%
from legiFR2024 import PremierTour

# %%
circo = PremierTour(dept="01", circ=1)
circo.issue()
print(circo.resultat)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 circo = PremierTour(dept="01", circ=1)
# ----> 2 circo.issue()
#       3 print(circo.resultat)
#
# File ~\Documents\Perso\Etudes\Pol\legiFR2024\legiFR2024\prep.py:113, in PremierTour.issue(self)
#     111 def issue(self):
#     112     self.recup_resultat()
# --> 113     self.prepare_resultat()
#     114     resu = self.resultat
#     115     resu["Eliminé"] = False
#
# File ~\Documents\Perso\Etudes\Pol\legiFR2024\legiFR2024\prep.py:61, in Scrutin.prepare_resultat(self)
#      59 ptc = self.particip
#      60 cols_a_garder = ["Liste des candidats", "Nuance", "Voix"]
# ---> 61 res = res.loc[:, cols_a_garder]
#      62 res.loc[:, "Voix"] = res["Voix"].map(parsage_nombres)
#      63 ptc.loc[:, "Nombre"] = ptc["Nombre"].map(parsage_nombres)
#
# ...

# %%
# Out:
#      Liste des candidats Nuance   Voix  Tot. Exprimés  Tot. Inscrits  \
# 0    M. Pierre CAZENEUVE    ENS  34053          64006          88339
# 1        M. Lucas PEYRET     UG  14749          64006          88339
# 2   Mme Christine PASTOR     RN  12057          64006          88339
# 3  Mme Charlotte RICHARD    ECO   1633          64006          88339
# 4       M. Rémi CARILLON    REC   1083          64006          88339
# 5        Mme Cécile ABAD    EXG    431          64006          88339
#
#   Pct. Exprimés Pct. Inscrits  Eliminé    Elu  Qualifié
# 0      0.532028      0.385481    False   True     False
# 1      0.230432      0.166959     True  False     False
# 2      0.188373      0.136486     True  False     False
# 3      0.025513      0.018486     True  False     False
# 4       0.01692       0.01226     True  False     False
# 5      0.006734      0.004879     True  False     False

# %%
df = circo9207.resultat.copy()

# %%
df["Rang"] = df["Voix"].rank(ascending=False)
df
# Out:
#      Liste des candidats Nuance   Voix  Tot. Exprimés  Tot. Inscrits  \
# 0    M. Pierre CAZENEUVE    ENS  34053          64006          88339
# 1        M. Lucas PEYRET     UG  14749          64006          88339
# 2   Mme Christine PASTOR     RN  12057          64006          88339
# 3  Mme Charlotte RICHARD    ECO   1633          64006          88339
# 4       M. Rémi CARILLON    REC   1083          64006          88339
# 5        Mme Cécile ABAD    EXG    431          64006          88339
#
#   Pct. Exprimés Pct. Inscrits  Eliminé    Elu  Qualifié  Rang
# 0      0.532028      0.385481    False   True     False   1.0
# 1      0.230432      0.166959     True  False     False   2.0
# 2      0.188373      0.136486     True  False     False   3.0
# 3      0.025513      0.018486     True  False     False   4.0
# 4       0.01692       0.01226     True  False     False   5.0
# 5      0.006734      0.004879     True  False     False   6.0

# %%
deux_premiers = df.sort_values(by="Voix", ascending=False)[:2].index
df.loc[deux_premiers]
# Out:
#    Liste des candidats Nuance   Voix  Tot. Exprimés  Tot. Inscrits  \
# 0  M. Pierre CAZENEUVE    ENS  34053          64006          88339
# 1      M. Lucas PEYRET     UG  14749          64006          88339
#
#   Pct. Exprimés Pct. Inscrits  Eliminé    Elu  Qualifié  Rang
# 0      0.532028      0.385481    False   True     False   1.0
# 1      0.230432      0.166959     True  False     False   2.0
